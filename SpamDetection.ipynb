# %%
import pandas as pd
import numpy as np

data = pd.read_csv('spamcomments.csv')
data
# Out:
#                                        COMMENT_ID                AUTHOR  \
# 0     LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1     LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A           adam riyati
# 2     LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8      Evgeny Murashkin
# 3             z13jhp0bxqncu512g22wvzkasxmvvzjaz04       ElNino Melendez
# 4             z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# ...                                           ...                   ...
# 1951  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA          Katie Mettam
# 1952  _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI  Sabina Pearson-Smith
# 1953  _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs         jeffrey jules
# 1954  _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0        Aishlin Maciel
# 1955  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA           Latin Bosch
#
#                             DATE  \
# 0            2013-11-07T06:20:48
# ...

# %%
data.isnull().sum()
# Out:
# COMMENT_ID      0
# AUTHOR          0
# DATE          245
# CONTENT         0
# CLASS           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 3

# %%
data.fillna(method = 'pad', inplace = True)
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# /tmp/ipykernel_12289/3122300124.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method = 'pad', inplace = True)
# 0

# %%
data.to_csv('Spam.csv')
df = pd.read_csv('Spam.csv', index_col = 0)
df = df.reset_index(drop=True)
df
# Out:
#                                        COMMENT_ID                AUTHOR  \
# 0     LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1     LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A           adam riyati
# 2     LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8      Evgeny Murashkin
# 3             z13jhp0bxqncu512g22wvzkasxmvvzjaz04       ElNino Melendez
# 4             z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# ...                                           ...                   ...
# 1949  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA          Katie Mettam
# 1950  _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI  Sabina Pearson-Smith
# 1951  _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs         jeffrey jules
# 1952  _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0        Aishlin Maciel
# 1953  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA           Latin Bosch
#
#                             DATE  \
# 0            2013-11-07T06:20:48
# ...

# %%
df["CLASS"] = df["CLASS"].map({0: "Not Spam", 1: "Spam Comment"})
df.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#           CLASS
# 0  Spam Comment
# 1  Spam Comment
# 2  Spam Comment
# 3  Spam Comment
# 4  Spam Comment

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB

x = df['CONTENT']
y = df['CLASS']

cv = CountVectorizer()
x = cv.fit_transform(x)

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

model = BernoulliNB()
model.fit(xtrain, ytrain)
model.predict(xtest)
model.score(xtest, ytest)
# Out:
# 0.8797953964194374

# %%
sample = "Check this out: https://thecleverprogrammer.com/"
data = cv.transform([sample]).toarray()
model.predict(data)
# Out:
# array(['Spam Comment'], dtype='<U12')

# %%
sample1 = "Hello girl you are too naughty"
data2 = cv.transform([sample]).toarray()
model.predict(data2)
# Out:
# array(['Spam Comment'], dtype='<U12')
